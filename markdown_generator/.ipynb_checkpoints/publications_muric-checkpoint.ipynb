# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/goranmuricuser/Downloads/citations_muric.csv').sort_values(by='Year', ascending=False).fillna('')

# %%
df
# Out:
#                                               Authors  \
# 19  Hickey, Daniel; Schmitz, Matheus; Fessler, Dan...
# 18  Schmitz, Matheus; Muric, Goran; Hickey, Daniel...
# 17  Hickey, Daniel; Schmitz, Matheus; Fessler, Dan...
# 16  Schmitz, Matheus; Murić, Goran; Burghardt, Kei...
# 15  Goldenberg, Amit; Bailey, David; Muric, Goran;...
# 14  Schmitz, Matheus; Muric, Goran; Burghardt, Kei...
# 11  Chen, Emily; Jiang, Julie; Chang, Ho-Chun Herb...
# 13  Jiang, Julie; Chen, Emily; Luceri, Luca; Murić...
# 12  Murić, Goran; Tregubov, Alexey; Blythe, Jim; A...
# 10      Ko, Kaitlyn; Burghardt, Keith; Muric, Goran;
# 9         Muric, Goran; Wu, Yusong; Ferrara, Emilio;
# 8   Ho-Chun Herbert Chang, Emily Chen, Meiqing Zha...
# 7   Schmitz, Matheus; Murić, Goran; Burghardt, Kei...
# 6   Muric, Goran; Lerman, Kristina; Ferrara, Emilio;
# 5      Heimann, Mark; Murić, Goran; Ferrara, Emilio;
# 1   Ozer, Mert; Sapienza, Anna; Abeliuk, Andrés; M...
# 4   Ferrara, Emilio; Chang, Herbert; Chen, Emily; ...
# 3   Murić, Goran; Tregubov, Alexey; Blythe, Jim; A...
# 2   Blythe, James; Ferrara, Emilio; Huang, Di; Ler...
# 0   Blythe, Jim; Bollenbacher, John; Huang, Di; Hu...
#
#                                                 Title  \
# 19  Auditing elon musk’s impact on hate speech and...
# 18  Do Users Adopt Extremist Beliefs from Exposure...
# 17  No Love Among Haters: Negative Interactions Re...
# 16  Quantifying How Hateful Communities Radicalize...
# 15  Homophily and Acrophily as Drivers of Politica...
# 14            Detecting Anti-vaccine Users on Twitter
# 11  Charting the information and misinformation la...
# 13  What are Your Pronouns? Examining Gender Prono...
# 12  Large-scale agent-based simulations of online ...
# 10  Enter At Your Own Risk: The Impacts of Joining...
# 9   COVID-19 Vaccine Hesitancy on Social Media: Bu...
# 8   Social Bots and Social Media Manipulation in 2...
# 7   A Python Package to Detect Anti-Vaccine Users ...
# 6   Gender Disparity in the Authorship of Biomedic...
# 5   Structural Node Embedding in Signed Social Net...
# 1   Discovering patterns of online popularity from...
# 4   Characterizing social media manipulation in th...
# 3   Massive Cross-Platform Simulations of Online S...
# 2   The DARPA SocialSim Challenge: Massive Multi-A...
# 0   Massive multi-agent data-driven simulations of...
#
#                                           Publication Volume Number  \
# 19  Proceedings of the International AAAI Conferen...   17.0
# 18
# 17                    arXiv preprint arXiv:2303.13641
# 16  IEEE/ACM International Conference on Advances ...
# 15
# 14  Proceedings of the International AAAI Conferen...   17.0
# 11                                 Jmir Infodemiology    2.0    1.0
# 13                    arXiv preprint arXiv:2207.10894
# 12          Autonomous Agents and Multi-Agent Systems   36.0    2.0
# 10  2021 IEEE 18th International Conference on Mob...
# 9                         JMIR Public Health Surveill    7.0   11.0
# 8   Handbook of Computational Social Science, Volu...
# 7                     arXiv preprint arXiv:2110.11333
# 6                Journal of Medical Internet Research   23.0    4.0
# 5            Complex Networks & Their Applications IX
# 1                    Expert Systems with Applications  151.0
# 4                                        First Monday   25.0   11.0
# 3   Proceedings of the 19th International Conferen...
# 2                                               AAMAS
# 0   Advances in Practical Applications of Survivab...
#
#         Pages  Year                                Publisher
# 19  1133-1137  2023
# 18             2023
# 17             2023
# 16             2023
# 15             2023                            OSF Preprints
# 14    787-795  2023
# 11     e32378  2022        JMIR Publications Toronto, Canada
# 13             2022
# 12         38  2022                     Springer US New York
# 10    657-658  2021                                     IEEE
# 9              2021      JMIR Public Health and Surveillance
# 8         185  2021                                Routledge
# 7              2021
# 6      e25379  2021  JMIR Publications Inc., Toronto, Canada
# 5        3-14  2021                           Springer, Cham
# 1      113337  2020                                 Pergamon
# 4              2020
# 3              2020
# 2   1835-1837  2019
# 0        3-15  2019        Springer International Publishing

# %%
i = 1
for index, row in df.iterrows():
    if 'Supplementary' not in row['Title']:
        authors = row['Authors'].split(';')
        authors = [a.strip() for a in authors if a!=' ']
        auths = ''
        for a in authors:
            a1 = a.split(',')[0]
            a2 = a.split(',')[1]
            auths = auths + a1 + ' ' + a2[1] + ', '
        auths = auths[:-2]

        gscholar_link = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q='

        title = row['Title']
        #s = (gscholar_link+auths.replace(', ','%2C')+ '+' + title).replace(' ','+')
        print(auths + ' (' + str(int(row['Year'])) + '). ' + title + '. ' + row['Publication'] + ' ' + str(int(row['Year'])) + ';')
        #print(str(i) + '. ' + auths + ' ' + '[' + title + '.](' + s + ')' + ' ' + row['Publication'] + ' ' + str(row['Year']) + ';' + str(row['Volume'])


        i+=1
# Out:
# 1. Hickey D, Schmitz M, Fessler D, Smaldino P, Muric G, Burghardt K (2023). Auditing elon musk’s impact on hate speech and bots. Proceedings of the International AAAI Conference on Web and Social Media 2023;
# 2. Schmitz M, Muric G, Hickey D, Burghardt K (2023). Do Users Adopt Extremist Beliefs from Exposure to Hateful Subreddits?.  2023;
# 3. Hickey D, Schmitz M, Fessler D, Smaldino P, Muric G, Burghardt K (2023). No Love Among Haters: Negative Interactions Reduce Hate Community Engagement. arXiv preprint arXiv:2303.13641 2023;
# 4. Schmitz M, Murić G, Burghardt K (2023). Quantifying How Hateful Communities Radicalize Online Users. IEEE/ACM International Conference on Advances in Social Networks Analysis and Mining (ASONAM) 2023;
# 5. Goldenberg A, Bailey D, Muric G, Ferrara E, Schöne J, Willer R, Halperin E, Gross J (2023). Homophily and Acrophily as Drivers of Political Segregation on Social Media.  2023;
# 6. Schmitz M, Muric G, Burghardt K (2023). Detecting Anti-vaccine Users on Twitter. Proceedings of the International AAAI Conference on Web and Social Media 2023;
# 7. Chen E, Jiang J, Chang H, Muric G, Ferrara E (2022). Charting the information and misinformation landscape to characterize misinfodemics on social media: COVID-19 infodemiology study at a planetary scale. Jmir Infodemiology 2022;
# 8. Jiang J, Chen E, Luceri L, Murić G, Pierri F, Chang H, Ferrara E (2022). What are Your Pronouns? Examining Gender Pronoun Usage on Twitter. arXiv preprint arXiv:2207.10894 2022;
# 9. Murić G, Tregubov A, Blythe J, Abeliuk A, Choudhary D, Lerman K, Ferrara E (2022). Large-scale agent-based simulations of online social networks. Autonomous Agents and Multi-Agent Systems 2022;
# 10. Ko K, Burghardt K, Muric G (2021). Enter At Your Own Risk: The Impacts of Joining a Hateful Subreddit. 2021 IEEE 18th International Conference on Mobile Ad Hoc and Smart Systems (MASS) 2021;
# 11. Muric G, Wu Y, Ferrara E (2021). COVID-19 Vaccine Hesitancy on Social Media: Building a Public Twitter Data Set of Antivaccine Content, Vaccine Misinformation, and Conspiracies. JMIR Public Health Surveill 2021;
# 12. Ho-Chun Herbert Chang E (2021). Social Bots and Social Media Manipulation in 2020: The Year in Review. Handbook of Computational Social Science, Volume 1: Theory, Case Studies and Ethics 2021;
# 13. Schmitz M, Murić G, Burghardt K (2021). A Python Package to Detect Anti-Vaccine Users on Twitter. arXiv preprint arXiv:2110.11333 2021;
# 14. Muric G, Lerman K, Ferrara E (2021). Gender Disparity in the Authorship of Biomedical Research Publications During the COVID-19 Pandemic: Retrospective Observational Study. Journal of Medical Internet Research 2021;
# 15. Heimann M, Murić G, Ferrara E (2021). Structural Node Embedding in Signed Social Networks: Finding Online Misbehavior at Multiple Scales. Complex Networks & Their Applications IX 2021;
# 16. Ozer M, Sapienza A, Abeliuk A, Muric G, Ferrara E (2020). Discovering patterns of online popularity from time series. Expert Systems with Applications 2020;
# 17. Ferrara E, Chang H, Chen E, Muric G, Patel J (2020). Characterizing social media manipulation in the 2020 U.S. presidential election. First Monday 2020;
# 18. Murić G, Tregubov A, Blythe J, Abeliuk A, Choudhary D, Lerman K, Ferrara E (2020). Massive Cross-Platform Simulations of Online Social Networks. Proceedings of the 19th International Conference on Autonomous Agents ant Multi-Agent systems 2020;
# 19. Blythe J, Ferrara E, Huang D, Lerman K, Muric G, Sapienza A, Tregubov A, Pacheco D, Bollenbacher J, Flammini A (2019). The DARPA SocialSim Challenge: Massive Multi-Agent Simulations of the Github Ecosystem.. AAMAS 2019;
# 20. Blythe J, Bollenbacher J, Huang D, Hui P, Krohn R, Pacheco D, Muric G, Sapienza A, Tregubov A, Ahn Y (2019). Massive multi-agent data-driven simulations of the github ecosystem. Advances in Practical Applications of Survivable Agents and Multi-Agent Systems: The PAAMS Collection: 17th International Conference, PAAMS 2019, Ávila, Spain, June 26–28, 2019, Proceedings 17 2019;
